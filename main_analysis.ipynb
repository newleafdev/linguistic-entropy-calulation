# %% [markdown]
# # Analysis of language entropy in in JRPGs and their translations
# ## Next Steps
# - Review the tutorial: https://t-shoemaker.github.io/2024_dtl_lm-interpretability/chapters/index.html
# - calculate the JRPG corpus average
# - compare with an easier JRPG
# - account for proper nouns (strip them?)

# %%
import word_frequency_analyzer
import entropy_calculations
import nltk
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
csv_file_path = 'data/cleaned_sentences/UO_sentences-jp.csv'  # Replace with your file path
language = 'ja'  # Change to 'en' for English or 'ja' for Japanese
calculator = entropy_calculations.EntropyCalculator(csv_file_path, language=language)
calculator.run()
# Out:
# Total Tokens: 374736
# Unique Tokens: 12902
# Unigram Entropy: 8.3632 bits
# Bigram Entropy: 13.3650 bits
# Trigram Entropy: 16.0853 bits
# Mean Information Density: 0.2360

# %%
csv_file_path = 'data/cleaned_sentences/FFT_sentences-jp.csv'  # Replace with your file path
language = 'ja'  # Change to 'en' for English or 'ja' for Japanese
calculator = entropy_calculations.EntropyCalculator(csv_file_path, language=language)
calculator.run()
# Out:
# Total Tokens: 81305
# Unique Tokens: 4819
# Unigram Entropy: 8.1127 bits
# Bigram Entropy: 12.1833 bits
# Trigram Entropy: 14.0760 bits
# Mean Information Density: 0.1652

# %%
csv_file_path = 'data/cleaned_sentences/FFT-WotL-en.csv'  # Replace with your file path
language = 'en'  # Change to 'en' for English or 'ja' for Japanese
calculator = entropy_calculations.EntropyCalculator(csv_file_path, language=language)
calculator.run()
# Out:
# Total Tokens: 52308
# Unique Tokens: 5451
# Unigram Entropy: 9.1864 bits
# Bigram Entropy: 13.7570 bits
# Trigram Entropy: 15.2214 bits
# Mean Information Density: 0.2968

# %% [markdown]
# ## Conclusions
# - as n increases, n-gram entropy increases. Likely due to small data set with many proper nouns.
# - need to compare this trend with an easier text, how much does the entropy increase when measured across another smaller corpus

# %%
# nltk troubleshooting

nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\joshu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\joshu\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\joshu\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True
